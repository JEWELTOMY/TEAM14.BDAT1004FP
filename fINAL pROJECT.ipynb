# %%
# !pip install pymongo[srv]

# %%
import time
import json

from pymongo import MongoClient
import requests

# %%
client = MongoClient("mongodb+srv://DATAPRGRMNG:DATA14@cluster0.v6qkh.mongodb.net/DATAPRGRMNG?ssl=true&ssl_cert_reqs=CERT_NONE")
db = client.get_database('DATAPRGRMNG')
records=db.newcases

while True:
    r=requests.get("https://api.twelvedata.com/time_series?symbol=AAPL,EUR/USD,ETH/BTC:Huobi,RY:TSX&interval=1min&apikey=71591a285e17485aa0dc839fc4f51c8c")
    if r.status_code==200:    
        data=r.json()
        print(data)
        #records.insert_one(data)
        db.DATAPRGRMNG.insert_one(data)
        time.sleep(60)
else:
    exit()
# Out:
# {'AAPL': {'meta': {'symbol': 'AAPL', 'interval': '1min', 'currency': 'USD', 'exchange_timezone': 'America/New_York', 'exchange': 'NASDAQ', 'type': 'Common Stock'}, 'values': [{'datetime': '2021-08-19 16:00:00', 'open': '146.70000', 'high': '146.70000', 'low': '146.70000', 'close': '146.70000', 'volume': '0'}, {'datetime': '2021-08-19 15:59:00', 'open': '146.47000', 'high': '146.74001', 'low': '146.45000', 'close': '146.70000', 'volume': '574987'}, {'datetime': '2021-08-19 15:58:00', 'open': '146.42500', 'high': '146.47501', 'low': '146.37270', 'close': '146.47000', 'volume': '352854'}, {'datetime': '2021-08-19 15:57:00', 'open': '146.41000', 'high': '146.44000', 'low': '146.35500', 'close': '146.42999', 'volume': '392908'}, {'datetime': '2021-08-19 15:56:00', 'open': '146.46001', 'high': '146.49001', 'low': '146.37000', 'close': '146.40500', 'volume': '368219'}, {'datetime': '2021-08-19 15:55:00', 'open': '146.50000', 'high': '146.60590', 'low': '146.42999', 'close': '146.47000', 'vo
# ...
